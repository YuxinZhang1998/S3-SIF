# %% [markdown]
# <a href="https://colab.research.google.com/github/YuxinZhang1998/S3-SIF/blob/main/RunPyeogpr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8451a649-171c-4c9f-baf7-abf05a9c495e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8451a649-171c-4c9f-baf7-abf05a9c495e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from my_eogpr import EarthEngine

# %%
bounding_box = [
  -10,
  36,
   4,
  44
];


dc = EarthEngine(projectID  = "ee-yuxinzhanguv1",
                 sensor ="SENTINEL3_L1B",
                 biovar = "FVC",
                 bounding_box = bounding_box,
                 temporal_extent =  ["2019-01-01", "2019-12-31"],
                 spatial_resolution  = 300,
                 cloudmask =True)

dc.construct_datacube(composite = 8)

dc.process_map(assetpath = "projects/ee-yuxinzhanguv1/assets/GPR-S3-8DAYS-peninsula2019-300-FVC")
# Out:
# Temporal composites: 8 days
# Exporting to projects/ee-yuxinzhanguv1/assets/GPR-S3-8DAYS-peninsula2019-300-FVC
# 20190101
# 20190109
# 20190117
# 20190125
# 20190202
# 20190210
# 20190218
# 20190226
# 20190306
# 20190314
# 20190322
# 20190330
# 20190407
# 20190415
# 20190423
# 20190501
# 20190509
# 20190517
# 20190525
# 20190602
# 20190610
# 20190618
# 20190626
# 20190704
# 20190712
# 20190720
# 20190728
# 20190805
# 20190813
# 20190821
# 20190829
# 20190906
# 20190914
# 20190922
# 20190930
# 20191008
# 20191016
# 20191024
# 20191101
# 20191109
# 20191117
# 20191125
# 20191203
# 20191211
# 20191219
